# %%
mre_rations = 120
mre_freq = 12  # seconds
mre_n = 10

mre_rations_per_hour = mre_rations * mre_n * (3600 / mre_freq)

print(mre_rations_per_hour)
# Out:
# 360000.0

# %%
workers = mre_rations_per_hour / 0.6

# %%
workers
# Out:
# 600000.0
