# %%
import numpy as np
import polars as pl

# %%
augs = pl.scan_csv("augmenter_setups_3.csv").filter(
    pl.all_horizontal(pl.col("Damage", "Rate of Fire", "Shield Max").is_not_null()),
    (pl.col("Electric Tempering") <= 0.0) | (pl.col("Electric Tempering").is_null()),
    ~pl.col("").str.contains("Art of Commanding"),
    ~pl.col("").str.contains("Art of Destruction"),
    ~pl.col("").str.contains("Art of Fast Killing"),
    ~pl.col("").str.contains("Art of Gunnery"),
    ~pl.col("").str.contains("Art of Healing"),
    ~pl.col("").str.contains("Art of Engineering"),
    ~pl.col("").str.contains("Art of Stealth"),
).collect()

# %%
augs = augs.with_columns(
    dps=(100 * (1 + pl.col("Damage")) * (1 + pl.col("Rate of Fire"))) * (1 + ((0.05 + pl.col("Critical Hit Chance")) * (0.5 * (1 + pl.col("Critical Hit Strength"))))),
    dph=(100 * (1 + pl.col("Damage"))) * (1 + ((0.05 + pl.col("Critical Hit Chance")) * (0.5 * (1 + pl.col("Critical Hit Strength")))))
)

# %%
a1 = '''"Qa'ik Urk'qii Akk'oj"'''
a2 = "'Raurava Bhava'"
a3 = "'Celeste Mark Augmenter'"
augs.filter(
    pl.col("").str.contains(f"{a1}, {a2}, {a3}")
)
# Out:
# shape: (1, 32)
# ┌──────────┬──────────┬────────────────┬───────────────┬───┬─────────┬────────┬────────────┬───────┐
# │          ┆ Capacity ┆ Critical Hit   ┆ Critical Hit  ┆ … ┆ Weapons ┆ Weight ┆ dps        ┆ dph   │
# │ ---      ┆ ---      ┆ Chance         ┆ Strength      ┆   ┆ Slots   ┆ ---    ┆ ---        ┆ ---   │
# │ str      ┆ f64      ┆ ---            ┆ ---           ┆   ┆ ---     ┆ f64    ┆ f64        ┆ f64   │
# │          ┆          ┆ f64            ┆ f64           ┆   ┆ f64     ┆        ┆            ┆       │
# ╞══════════╪══════════╪════════════════╪═══════════════╪═══╪═════════╪════════╪════════════╪═══════╡
# │ ("Qa'ik  ┆ 0.0      ┆ 0.2            ┆ 0.9           ┆ … ┆ 0.0     ┆ 0.0    ┆ 389.508197 ┆ 396.0 │
# │ Urk'qii  ┆          ┆                ┆               ┆   ┆         ┆        ┆            ┆       │
# │ Akk'oj", ┆          ┆                ┆               ┆   ┆         ┆        ┆            ┆       │
# │ 'Raur…   ┆          ┆                ┆               ┆   ┆         ┆        ┆            ┆       │
# └──────────┴──────────┴────────────────┴───────────────┴───┴─────────┴────────┴────────────┴───────┘

# %%
a1 = '''"Qa'ik Urk'qii Akk'oj"'''
a2 = "'Luminous Intersticial Desistance Augmenter'"
augs.filter(
    pl.col("").str.contains(f"{a1}, {a1}, {a2}")
)
# Out:
# shape: (1, 32)
# ┌──────────┬──────────┬───────────────┬───────────────┬───┬───────────────┬────────┬───────┬───────┐
# │          ┆ Capacity ┆ Critical Hit  ┆ Critical Hit  ┆ … ┆ Weapons Slots ┆ Weight ┆ dps   ┆ dph   │
# │ ---      ┆ ---      ┆ Chance        ┆ Strength      ┆   ┆ ---           ┆ ---    ┆ ---   ┆ ---   │
# │ str      ┆ f64      ┆ ---           ┆ ---           ┆   ┆ f64           ┆ f64    ┆ f64   ┆ f64   │
# │          ┆          ┆ f64           ┆ f64           ┆   ┆               ┆        ┆       ┆       │
# ╞══════════╪══════════╪═══════════════╪═══════════════╪═══╪═══════════════╪════════╪═══════╪═══════╡
# │ ("Qa'ik  ┆ 0.15     ┆ 0.6           ┆ 2.2           ┆ … ┆ -0.01         ┆ 0.0    ┆ 479.4 ┆ 479.4 │
# │ Urk'qii  ┆          ┆               ┆               ┆   ┆               ┆        ┆       ┆       │
# │ Akk'oj", ┆          ┆               ┆               ┆   ┆               ┆        ┆       ┆       │
# │ "Qa'i…   ┆          ┆               ┆               ┆   ┆               ┆        ┆       ┆       │
# └──────────┴──────────┴───────────────┴───────────────┴───┴───────────────┴────────┴───────┴───────┘

# %%
tmp = augs.filter(
    # ~pl.col("").str.contains("Luminous"),
    # ~pl.col("").str.contains("Illunis"),
    # ~pl.col("").str.contains("Promontory"),
    # pl.col("Damage") >= 2.0,
    # pl.col("Rate of Fire") >= 0.0,
    # pl.col("Shield Max") >= 1.7,
    pl.col("Shield Recovery") >= 1.0,
    pl.col("Resistance to Damage") >= 0.3,
    # pl.col("Electric Tempering") <= -0.1,
    pl.col("Range") >= 0.25,
    # pl.col("Critical Hit Chance") >= 0.2,
    # pl.col("Critical Hit Strength") >= 0.9,
    # pl.col("Rate of Fire") <= 0.2,
    # pl.col("dps") >= 400,
    pl.col("dph") >= 400
).drop(
    "Docking Speed",
    "Hostility",
    "Inertial Dampening",
    "Multifiring",
    "Projectile Velocity",
    "Radar",
    "Tractor Power",
    "Tractor Range",
    "Visibility",
    "Weapon Hold",
    "Weapons Slots"
)

with pl.Config(fmt_str_lengths=1000, tbl_width_chars=1000, tbl_rows=20):
    display(tmp.sort("dph", descending=True))
# Out:
# shape: (41, 21)
# ┌────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────┬─────────────────────┬───────────────────────┬───┬─────────┬────────┬────────────┬───────────┐
# │                                                                                                                    ┆ Capacity ┆ Critical Hit Chance ┆ Critical Hit Strength ┆ … ┆ Turning ┆ Weight ┆ dps        ┆ dph       │
# │ ---                                                                                                                ┆ ---      ┆ ---                 ┆ ---                   ┆   ┆ ---     ┆ ---    ┆ ---        ┆ ---       │
# │ str                                                                                                                ┆ f64      ┆ f64                 ┆ f64                   ┆   ┆ f64     ┆ f64    ┆ f64        ┆ f64       │
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════╪═════════════════════╪═══════════════════════╪═══╪═════════╪════════╪════════════╪═══════════╡
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Lustrous Unalloyed Promontory Augmenter')                        ┆ 0.0      ┆ 0.58                ┆ 1.2                   ┆ … ┆ 0.0     ┆ 2.0    ┆ 524.83     ┆ 524.83    │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Aberrant Ordnance Augmenter')                                    ┆ 0.0      ┆ 0.6                 ┆ 1.2                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 514.5      ┆ 514.5     │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Ultimate Art of Sharpshooting Augmenter')                        ┆ 0.0      ┆ 0.5                 ┆ 1.2                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 577.8      ┆ 481.5     │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", "Operative's Stalking Tracker Augmenter")                         ┆ 0.21     ┆ 0.55                ┆ 1.2                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 394.0508   ┆ 474.76    │
# │ ('Equinox Shielding Augmenter', 'Total Eclipse Illunis Augmenter', 'Lustrous Unalloyed Promontory Augmenter')      ┆ 0.0      ┆ 0.28                ┆ 1.35                  ┆ … ┆ 0.0     ┆ 2.0    ┆ 581.120313 ┆ 464.89625 │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Luminous Brace Levee Augmenter')                                 ┆ 0.0      ┆ 0.54                ┆ 1.9                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 460.164    ┆ 460.164   │
# │ ('Faded Delquadrikamdon Augmenter', "Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj")                                ┆ 0.0      ┆ 0.4                 ┆ 1.2                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 455.975    ┆ 455.975   │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Twisted Death Augmenter')                                        ┆ 0.08     ┆ 0.6                 ┆ 2.1                   ┆ … ┆ 0.0     ┆ -0.4   ┆ 451.6875   ┆ 451.6875  │
# │ ("Nightfury's Patience", 'Total Eclipse Illunis Augmenter', 'Lustrous Unalloyed Promontory Augmenter')             ┆ -0.1     ┆ 0.28                ┆ 1.35                  ┆ … ┆ -0.33   ┆ 2.0    ┆ 811.83375  ┆ 451.01875 │
# │ ("Qa'ik Urk'qii Akk'oj", 'Mechanical Hound Augmenter', 'Lustrous Unalloyed Promontory Augmenter')                  ┆ 0.0      ┆ 0.38                ┆ 0.6                   ┆ … ┆ 0.5     ┆ 2.0    ┆ 450.24     ┆ 450.24    │
# │ …                                                                                                                  ┆ …        ┆ …                   ┆ …                     ┆ … ┆ …       ┆ …      ┆ …          ┆ …         │
# │ ("Qa'ik Urk'qii Akk'oj", 'Mechanical Hound Augmenter', "Operative's Stalking Tracker Augmenter")                   ┆ 0.21     ┆ 0.35                ┆ 0.6                   ┆ … ┆ 0.5     ┆ 0.0    ┆ 340.7316   ┆ 410.52    │
# │ ("Qa'ik Urk'qii Akk'oj", 'Vaidya Bhava', 'Lustrous Unalloyed Promontory Augmenter')                                ┆ 0.0      ┆ 0.38                ┆ 0.9                   ┆ … ┆ 0.0     ┆ 2.0    ┆ 449.3115   ┆ 408.465   │
# │ ('Luminous Ossified Buttress Augmenter', 'Lustrous Unalloyed Promontory Augmenter', 'Aberrant Ordnance Augmenter') ┆ 0.0      ┆ 0.38                ┆ 0.0                   ┆ … ┆ 0.3     ┆ 2.0    ┆ 408.24     ┆ 408.24    │
# │ ("Ares' Rage Augmenter", 'Luminous Ossified Buttress Augmenter', 'Lustrous Unalloyed Promontory Augmenter')        ┆ 0.0      ┆ 0.18                ┆ 0.0                   ┆ … ┆ 0.3     ┆ 2.0    ┆ 408.09     ┆ 408.09    │
# │ ("Qa'ik Urk'qii Akk'oj", 'Luminous Ossified Buttress Augmenter', 'Lustrous Unalloyed Promontory Augmenter')        ┆ 0.0      ┆ 0.38                ┆ 0.6                   ┆ … ┆ 0.3     ┆ 2.0    ┆ 404.544    ┆ 404.544   │
# │ ("Qa'ik Urk'qii Akk'oj", 'Luminous Munitions Amplifier Augmenter', 'Lustrous Commination Ambit Augmenter')         ┆ 0.1      ┆ 0.2                 ┆ 1.7                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 1001.734   ┆ 403.925   │
# │ ("Qa'ik Urk'qii Akk'oj", "Qa'ik Urk'qii Akk'oj", 'Glamorous Verdured Potentiality Augmenter')                      ┆ 0.0      ┆ 0.4                 ┆ 1.2                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 605.475    ┆ 403.65    │
# │ ("Grand Navigator's Augmenter", "Qa'ik Urk'qii Akk'oj", 'Lustrous Unalloyed Promontory Augmenter')                 ┆ 0.0      ┆ 0.38                ┆ 0.6                   ┆ … ┆ 0.0     ┆ 2.0    ┆ 564.48     ┆ 403.2     │
# │ ("Qa'ik Urk'qii Akk'oj", 'Empyreal Schism Augmenter', 'Aberrant Ordnance Augmenter')                               ┆ 0.0      ┆ 0.53                ┆ 0.6                   ┆ … ┆ 0.0     ┆ 0.0    ┆ 523.38     ┆ 402.6     │
# │ ('Mechanical Hound Augmenter', 'Mechanical Hound Augmenter', 'Lustrous Unalloyed Promontory Augmenter')            ┆ 0.0      ┆ 0.18                ┆ 0.0                   ┆ … ┆ 1.0     ┆ 2.0    ┆ 401.4      ┆ 401.4     │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────┴─────────────────────┴───────────────────────┴───┴─────────┴────────┴────────────┴───────────┘
