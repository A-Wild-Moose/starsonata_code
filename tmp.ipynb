# %%
# 5319 = (460*8.1312 + 110*2.3)*(1-a) + (460*8.1312 + 110*2.3)*a*1.5
# 5319 = b*(1-a) + b*a*1.5
# 5319 = b-ba + 1.5ba = b + 0.5ba = b(1+0.5a)
# 5319/b - 1 = 0.5a
b = 460*8.1312 + 110*2.3
print(b)
# Out:
# 3993.352

# %%
print((5319 / b - 1) / 0.5)
print((5418 / b - 1) / 0.5)
print((5604 / b - 1) / 0.5)
print((5820 / b - 1) / 0.5)
# Out:
# 0.663927447417608
# 0.7135098533763116
# 0.8066646766926633
# 0.9148444715116524

# %%
b2 = 60*8.1312 + 110*0.6
print((735 / b2 - 1) / 0.5)
print((729 / b2 - 1) / 0.5)
print((748 / b2 - 1) / 0.5)
print((771 / b2 - 1) / 0.5)
# Out:
# 0.6540428113354713
# 0.6323771557327325
# 0.7009850651414049
# 0.7840367449519023

# %%
b3 = 89*8.1312 + 110*0.7
print((1066 / b3 - 1) / 0.5)
print((1068 / b3 - 1) / 0.5)
print((1099 / b3 - 1) / 0.5)
print((1137 / b3 - 1) / 0.5)
# Out:
# 0.6627473157708579
# 0.6677430893464131
# 0.7451775797675166
# 0.8400972777030633

# %%
b4 = 826*8.1312 + 110*2.5
print((9315 / b4 - 1) / 0.5)
print((9592 / b4 - 1) / 0.5)
print((9970 / b4 - 1) / 0.5)
print((10375 / b4 - 1) / 0.5)
# Out:
# 0.6647133254775546
# 0.7439538612969088
# 0.8520871556641136
# 0.9679442567718333
